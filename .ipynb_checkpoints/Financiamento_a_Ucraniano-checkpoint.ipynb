# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('figure', figsize= (14, 6))
import seaborn as sns

# %%
data = pd.read_csv('dados/fts_incoming_funding_ukr.csv')
data
# Out:
#           date         budgetYear  \
# 0        #date  #date+year+budget
# 1   2023-01-10                NaN
# 2   2023-01-04                NaN
# 3   2023-01-04                NaN
# 4   2023-01-04                NaN
# ..         ...                ...
# 89  2020-08-28               2020
# 90  2020-07-13                NaN
# 91  2020-07-13                NaN
# 92  2020-01-01                NaN
# 93  2020-01-01                NaN
#
#                                           description  \
# 0                                  #description+notes
# 1   Improving Human Security through Community-Bas...
# 2                               OCT 10863 [OCT 10863]
# 3                   OCT 10863 [OCT 10863];[YY/OCHA/1]
# 4   Emergency and Rehabilitation Activities for Uk...
# ..                                                ...
# 89  The aim is to strengthen the resilience of the...
# 90        Humanitarian Mine Action in Eastern Ukraine
# 91                           Humanitarian Mine Action
# 92        Humanitarian Mine Action in Eastern Ukraine
# 93        Humanitarian Mine Action in Eastern Ukraine
#
#                    amountUSD                          srcOrganization  \
# 0   #value+funding+total+usd                         #org+name+funder
# 1                    3920000                     Japan, Government of
# 2                     462962                     Japan, Government of
# 3                    2055463                     Japan, Government of
# 4                    2275000                     Japan, Government of
# ..                       ...                                      ...
# 89                   4470588                   Germany, Government of
# 90                         0  United States of America, Government of
# 91                   2000000  United States of America, Government of
# 92                         0               Netherlands, Government of
# 93                   1138952               Netherlands, Government of
#
#      srcOrganizationTypes               srcLocations        srcUsageYearStart  \
# 0   #org+type+funder+list  #country+iso3+funder+list  #date+year+start+funder
# 1             Governments                        JPN                     2023
# 2             Governments                        JPN                     2023
# 3             Governments                        JPN                     2023
# 4             Governments                        JPN                     2023
# ..                    ...                        ...                      ...
# 89            Governments                        DEU                     2020
# 90            Governments                        USA                     2018
# 91            Governments                        USA                     2018
# 92            Governments                        NaN                     2020
# 93            Governments                        NaN                     2023
#
#           srcUsageYearEnd               destPlan  ... firstReportedDate  \
# 0   #date+year+end+funder  #activity+appeal+name  ...    #date+reported
# 1                    2023                    NaN  ...        2023-01-20
# 2                    2023                    NaN  ...        2023-01-06
# 3                    2023                    NaN  ...        2023-01-06
# 4                    2023                    NaN  ...        2023-01-20
# ..                    ...                    ...  ...               ...
# 89                   2020                    NaN  ...        2020-08-28
# 90                   2018                    NaN  ...        2020-09-11
# 91                   2018                    NaN  ...        2020-09-11
# 92                   2024                    NaN  ...        2022-01-25
# 93                   2023                    NaN  ...        2022-01-25
#
#       decisionDate               keywords        originalAmount  \
# 0   #date+decision  #description+keywords  #value+funding+total
# 1       2023-01-10                    NaN                   NaN
# 2       2023-01-04                    NaN                   NaN
# 3       2023-01-04                    NaN                   NaN
# 4       2023-01-04                    NaN                   NaN
# ..             ...                    ...                   ...
# 89      2020-08-28              Multiyear               3800000
# 90      2020-07-13              Multiyear                   NaN
# 91      2020-07-13  Mine action,Multiyear                   NaN
# 92      2020-01-01              Multiyear                     0
# 93      2020-01-01                    NaN               1000000
#
#                  originalCurrency   exchangeRate                         id  \
# 0   #value+funding+total+currency  #financial+fx  #activity+id+fts_internal
# 1                             NaN            NaN                     267675
# 2                             NaN            NaN                     266786
# 3                             NaN            NaN                     266791
# 4                             NaN            NaN                     267632
# ..                            ...            ...                        ...
# 89                            EUR           0.85                     217750
# 90                            NaN            NaN                     218283
# 91                            NaN            NaN                     265311
# 92                            EUR          0.878                     246832
# 93                            EUR          0.878                     246837
#
#                     refCode      createdAt      updatedAt
# 0            #activity+code  #date+created  #date+updated
# 1                       NaN     2023-01-30     2023-02-01
# 2                 OCT 10863     2023-01-13     2023-01-13
# 3   [OCT 10863];[YY/OCHA/1]     2023-01-13     2023-01-13
# 4                       NaN     2023-01-30     2023-02-01
# ..                      ...            ...            ...
# 89              2020.1836.4     2020-08-29     2022-02-18
# 90                      NaN     2020-09-11     2022-12-19
# 91                      NaN     2022-12-19     2022-12-19
# 92                      NaN     2022-02-16     2022-03-10
# 93                      NaN     2022-02-16     2022-02-16
#
# [94 rows x 37 columns]

# %%
data['destPlan'].isnull().sum()
# Out:
# 93

# %%
data['originalAmount'].isnull().sum()
# Out:
# 39

# %%
data_ = data.drop(columns=['destPlan', 'refCode'])
data_ = data.drop(columns=['budgetYear'])

# %%
datadf = data_.drop(columns=['destPlan', 'refCode'])

# %%
datadf.drop(0, axis=0, inplace=True)

# %%
datadf
# Out:
#           date                                        description amountUSD  \
# 1   2023-01-10  Improving Human Security through Community-Bas...   3920000
# 2   2023-01-04                              OCT 10863 [OCT 10863]    462962
# 3   2023-01-04                  OCT 10863 [OCT 10863];[YY/OCHA/1]   2055463
# 4   2023-01-04  Emergency and Rehabilitation Activities for Uk...   2275000
# 5   2022-12-30          OCT 30104 [OCT 30104];[N&#176; 12-1/8186]    239872
# ..         ...                                                ...       ...
# 89  2020-08-28  The aim is to strengthen the resilience of the...   4470588
# 90  2020-07-13        Humanitarian Mine Action in Eastern Ukraine         0
# 91  2020-07-13                           Humanitarian Mine Action   2000000
# 92  2020-01-01        Humanitarian Mine Action in Eastern Ukraine         0
# 93  2020-01-01        Humanitarian Mine Action in Eastern Ukraine   1138952
#
#                             srcOrganization srcOrganizationTypes srcLocations  \
# 1                      Japan, Government of          Governments          JPN
# 2                      Japan, Government of          Governments          JPN
# 3                      Japan, Government of          Governments          JPN
# 4                      Japan, Government of          Governments          JPN
# 5                    Estonia, Government of          Governments          EST
# ..                                      ...                  ...          ...
# 89                   Germany, Government of          Governments          DEU
# 90  United States of America, Government of          Governments          USA
# 91  United States of America, Government of          Governments          USA
# 92               Netherlands, Government of          Governments          NaN
# 93               Netherlands, Government of          Governments          NaN
#
#    srcUsageYearStart srcUsageYearEnd destPlanCode destPlanId  ...      status  \
# 1               2023            2023          NaN        NaN  ...  commitment
# 2               2023            2023          NaN        NaN  ...  commitment
# 3               2023            2023          NaN        NaN  ...  commitment
# 4               2023            2023          NaN        NaN  ...  commitment
# 5               2022            2022          NaN        NaN  ...        paid
# ..               ...             ...          ...        ...  ...         ...
# 89              2020            2020          NaN        NaN  ...  commitment
# 90              2018            2018          NaN        NaN  ...  commitment
# 91              2018            2018          NaN        NaN  ...  commitment
# 92              2020            2024          NaN        NaN  ...  commitment
# 93              2023            2023          NaN        NaN  ...  commitment
#
#    firstReportedDate decisionDate               keywords originalAmount  \
# 1         2023-01-20   2023-01-10                    NaN            NaN
# 2         2023-01-06   2023-01-04                    NaN            NaN
# 3         2023-01-06   2023-01-04                    NaN            NaN
# 4         2023-01-20   2023-01-04                    NaN            NaN
# 5         2022-12-30   2022-12-28                    NaN         225000
# ..               ...          ...                    ...            ...
# 89        2020-08-28   2020-08-28              Multiyear        3800000
# 90        2020-09-11   2020-07-13              Multiyear            NaN
# 91        2020-09-11   2020-07-13  Mine action,Multiyear            NaN
# 92        2022-01-25   2020-01-01              Multiyear              0
# 93        2022-01-25   2020-01-01                    NaN        1000000
#
#    originalCurrency exchangeRate      id   createdAt   updatedAt
# 1               NaN          NaN  267675  2023-01-30  2023-02-01
# 2               NaN          NaN  266786  2023-01-13  2023-01-13
# 3               NaN          NaN  266791  2023-01-13  2023-01-13
# 4               NaN          NaN  267632  2023-01-30  2023-02-01
# 5               EUR        0.938  266415  2022-12-31  2023-01-04
# ..              ...          ...     ...         ...         ...
# 89              EUR         0.85  217750  2020-08-29  2022-02-18
# 90              NaN          NaN  218283  2020-09-11  2022-12-19
# 91              NaN          NaN  265311  2022-12-19  2022-12-19
# 92              EUR        0.878  246832  2022-02-16  2022-03-10
# 93              EUR        0.878  246837  2022-02-16  2022-02-16
#
# [93 rows x 34 columns]

# %%
datadf['srcUsageYearEnd'] = pd.to_datetime(datadf['srcUsageYearEnd'])
datadf['amountUSD'] = pd.to_numeric(datadf['amountUSD'])

# %%
plt.scatter(datadf['srcUsageYearEnd'], datadf['amountUSD'])

# %%
datadf['date'] = pd.to_datetime(datadf['date'])

# %%
ax = sns.lineplot(data=datadf, x='date', y='amountUSD')
ax.figure.set_size_inches((12,6))

# %%
ax = sns.pieplot(data=datadf, x='date', y='amountUSD')
ax.figure.set_size_inches((12,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 ax = sns.pieplot(data=datadf, x='date', y='amountUSD')
#       2 ax.figure.set_size_inches((12,6))
#
# AttributeError: module 'seaborn' has no attribute 'pieplot'
